# %%
import pandas as pd
import numpy as np

# %%
# !pwd
# Out:
# /Users/smurphier/Desktop/Project1

# %%
idd3yr = pd.read_csv("data/MaybeData/indicator_data_download_20190318.csv")

# %%
idd3yr.head(2)
# Out:
#                            Indicator Name  \
# 0  Age-Adjusted Death Rate due to Suicide
# 1  Age-Adjusted Death Rate due to Suicide
#
#                               What Is This Indicator Location Type Location  \
# 0  This indicator shows the age-adjusted death ra...        County   Harris
# 1  This indicator shows the age-adjusted death ra...        County   Harris
#
#    Indicator Value       Indicator Value Units  Lower Confidence Interval  \
# 0             10.5  deaths/ 100,000 population                        9.9
# 1             10.5  deaths/ 100,000 population                        9.9
#
#    Upper Confidence Interval Indicator Value Unstable Period of Measure  \
# 0                       11.1                       No         2014-2016
# 1                       11.1                       No         2014-2016
#
#         ...                                           Technical Note  \
# 0       ...        POM is now 3 years because of a change in sour...
# ...

# %%
cols_to_keep = ["Period of Measure", "Breakout Category", "Breakout Subcategory", "Breakout Value"]
idd3yr[cols_to_keep]
# Out:
#    Period of Measure Breakout Category       Breakout Subcategory  \
# 0          2014-2016            Gender                     Female
# 1          2014-2016            Gender                       Male
# 2          2014-2016    Race/Ethnicity  Asian or Pacific Islander
# 3          2014-2016    Race/Ethnicity  Black or African American
# 4          2014-2016    Race/Ethnicity         Hispanic or Latino
# 5          2014-2016    Race/Ethnicity                      White
# 6          2013-2015            Gender                     Female
# 7          2013-2015            Gender                       Male
# 8          2013-2015    Race/Ethnicity  Asian or Pacific Islander
# 9          2013-2015    Race/Ethnicity  Black or African American
# 10         2013-2015    Race/Ethnicity         Hispanic or Latino
# 11         2013-2015    Race/Ethnicity                      White
# 12         2012-2014            Gender                     Female
# ...
